# %%
# M6 CHALLENGE

# %%
# Import Dependencies:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import citipy 
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Import linregress
from scipy.stats import linregress

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.
lat_lngs = zip(lats, lngs) 
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 591

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities and Retrieve the following information from the API call:
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description (e.g., clouds, fog, light rain, clear sky)
# - The amount of rainfall over the last hour (1 hr).
# - The amount of snowfall over the last hour (1 hr).
    
  
    # Parse the JSON and retrieve data.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_disc = city_weather['weather'][0]['description']
        try:
            city_rain = city_weather['rain']['rain.1h']
        except KeyError:
            city_rain = 0
        try:
            city_snow = city_weather['snow']['snow.1h']
        except KeyError:
            city_snow = 0
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_disc,
                          "Rainfall(1hr)": city_rain,
                          "Snowfall(1hr)": city_snow,
                          "Country": city_country})
# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        continue
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | komsomolskiy
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | kudahuvadhoo
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | tuatapere
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | pakokku
# Processing Record 8 of Set 1 | lena
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | olden
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | igrim
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | iacu
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# ...

# %%
len (city_data)
# Out:
# 549

# %%
# Adding the data to a dataframe:
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Komsomolskiy  40.43   71.72     75.20        41           0        6.93
# 1        Barrow  71.29 -156.79     46.40        75           1       25.28
# 2  Kudahuvadhoo   2.67   72.89     82.98        76          74       15.57
# 3   Yellowknife  62.46 -114.35     73.40        46          40       10.29
# 4     Tuatapere -46.13  167.68     54.55        70         100        7.99
# 5       Rikitea -23.12 -134.97     73.29        84          74       14.67
# 6       Pakokku  21.33   95.10     79.56        80          97        9.42
# 7          Lena  43.10   -5.73     68.00        88          75        6.93
# 8       Mataura -46.19  168.86     53.58        74         100        3.20
# 9         Olden  61.84    6.81     57.00        97          98        4.21
#
#   Current Description  Rainfall(1hr)  Snowfall(1hr) Country
# 0           clear sky              0              0      UZ
# ...

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rainfall(1hr)", "Snowfall(1hr)"]

city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Komsomolskiy      UZ  40.43   71.72     75.20        41           0
# 1        Barrow      US  71.29 -156.79     46.40        75           1
# 2  Kudahuvadhoo      MV   2.67   72.89     82.98        76          74
# 3   Yellowknife      CA  62.46 -114.35     73.40        46          40
# 4     Tuatapere      NZ -46.13  167.68     54.55        70         100
#
#    Wind Speed Current Description  Rainfall(1hr)  Snowfall(1hr)
# 0        6.93           clear sky              0              0
# 1       25.28           clear sky              0              0
# 2       15.57          light rain              0              0
# 3       10.29    scattered clouds              0              0
# 4        7.99     overcast clouds              0              0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
